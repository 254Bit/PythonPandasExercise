# %%
import pandas as pd

# %%
df = pd.read_csv('Automobile_data.csv', na_values={
    'price':['?','n.a'],
    'stroke':['?','n.a'],
    'horsepower':['?','n.a'],
    'peak-rpm':['?','n.a'],
    'average-mileage':['?','n.a']})
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# #From the given dataset print the first and last five rows

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
missing_value =['?','n.a', np.NaN]
df=pd.read_csv('Automobile_data.csv',na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df=df.drop('symboling', axis = 1)

# %% [markdown]
# #Find the most expensive car company name
# #Print most expensive car's company name and price

# %%
df['price'].max()
# Out:
# 45400.0

# %%
most_expensive_car=df[['make','price']][df.price==df['price'].max()]
most_expensive_car
# Out:
#              make    price
# 74  mercedes-benz  45400.0

# %% [markdown]
# #Print all toyota cars details

# %%
df.groupby('make').get_group('toyota')
# Out:
#      normalized-losses    make fuel-type aspiration num-of-doors   body-style  \
# 150               87.0  toyota       gas        std          two    hatchback
# 151               87.0  toyota       gas        std          two    hatchback
# 152               74.0  toyota       gas        std         four    hatchback
# 153               77.0  toyota       gas        std         four        wagon
# 154               81.0  toyota       gas        std         four        wagon
# 155               91.0  toyota       gas        std         four        wagon
# 156               91.0  toyota       gas        std         four        sedan
# 157               91.0  toyota       gas        std         four    hatchback
# 158               91.0  toyota    diesel        std         four        sedan
# 159               91.0  toyota    diesel        std         four    hatchback
# 160               91.0  toyota       gas        std         four        sedan
# ...

# %% [markdown]
# # Count total cars per make

# %%
df['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# # Find each company's highest price car

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.groupby('make')[['make','price']].max()
# Out:
#                         make    price
# make
# alfa-romero      alfa-romero  16500.0
# audi                    audi  23875.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge  12964.0
# honda                  honda  12945.0
# isuzu                  isuzu  11048.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mercury              mercury  16503.0
# mitsubishi        mitsubishi  14869.0
# nissan                nissan  19699.0
# peugot                peugot  18150.0
# plymouth            plymouth  12764.0
# porsche              porsche  37028.0
# renault              renault   9895.0
# saab                    saab  18620.0
# subaru                subaru  11694.0
# toyota                toyota  17669.0
# volkswagen        volkswagen  13845.0
# volvo                  volvo  22625.0

# %% [markdown]
# # Sort all cars by Price column

# %%
df.sort_values('price', ascending = False)
# Out:
#      normalized-losses           make fuel-type aspiration num-of-doors  \
# 74                 NaN  mercedes-benz       gas        std          two
# 16                 NaN            bmw       gas        std          two
# 73                 NaN  mercedes-benz       gas        std         four
# 128                NaN        porsche       gas        std          two
# 17                 NaN            bmw       gas        std         four
# ..                 ...            ...       ...        ...          ...
# 138               83.0         subaru       gas        std          two
# 9                  NaN           audi       gas      turbo          two
# 44                 NaN          isuzu       gas        std          two
# 45                 NaN          isuzu       gas        std         four
# 129                NaN        porsche       gas        std          two
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %% [markdown]
# #Concatenate two data frames using the following conditions

# %%
GermanCars = {'make':['Ford','Mercedes','BMV', 'Audi'], 'Price':[2384,171995,135925,71400]}
japaneseCars = {'make':['Toyota','Honda','Nissan','Mitsubishi'], 'Price':[29995,23600,61500,58900]}

# %%
germanCars=pd.DataFrame.from_dict(GermanCars)

# %%
germanCars
# Out:
#        make   Price
# 0      Ford    2384
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
japaneseCars=pd.DataFrame.from_dict(japaneseCars)
japaneseCars
# Out:
#          make  Price
# 0      Toyota  29995
# 1       Honda  23600
# 2      Nissan  61500
# 3  Mitsubishi  58900

# %%
carsDF=pd.concat([germanCars,japaneseCars],keys=['Germany','Japan'])
carsDF
# Out:
#                  make   Price
# Germany 0        Ford    2384
#         1    Mercedes  171995
#         2         BMV  135925
#         3        Audi   71400
# Japan   0      Toyota   29995
#         1       Honda   23600
#         2      Nissan   61500
#         3  Mitsubishi   58900

# %% [markdown]
# #Merge two data frames using the following condition

# %%
Car_Price = {'make':['Toyota','Honda','BMV','Audi'], 'Price':[29995,23600,61500,58900]}
car_HorsePower = {'make':['Toyota','Honda','BMV','Audi'], 'Horsepower':[141,80,182,160]}

# %%
carPrice=pd.DataFrame.from_dict(Car_Price)
carPrice
# Out:
#      make  Price
# 0  Toyota  29995
# 1   Honda  23600
# 2     BMV  61500
# 3    Audi  58900

# %%
carHorsePower=pd.DataFrame.from_dict(car_HorsePower)
carHorsePower
# Out:
#      make  Horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
carsDF=pd.merge(carPrice, carHorsePower, on ='make')
carsDF
# Out:
#      make  Price  Horsepower
# 0  Toyota  29995         141
# 1   Honda  23600          80
# 2     BMV  61500         182
# 3    Audi  58900         160
